# %%
import torch
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/theAIGuysCode/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 444, done.
# remote: Total 444 (delta 0), reused 0 (delta 0), pack-reused 444
# Receiving objects: 100% (444/444), 34.09 MiB | 30.97 MiB/s, done.
# Resolving deltas: 100% (157/157), done.

# %%
# !pip3 install -qr ./OIDv4_ToolKit/requirements.txt
# Out:
#      |████████████████████████████████| 3.8 MB 5.3 MB/s
#      |████████████████████████████████| 79 kB 7.1 MB/s
#      |████████████████████████████████| 547 kB 41.8 MB/s
#      |████████████████████████████████| 8.2 MB 38.9 MB/s
#      |████████████████████████████████| 138 kB 42.2 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
# !python ./OIDv4_ToolKit/main.py downloader --classes 'Strawberry' --type_csv train
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Strawberry.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 51226 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Strawberry'  --type_csv validation
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Strawberry.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 16 MB, 38878 KB/s, 0 seconds passed
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9987, done.
# remote: Total 9987 (delta 0), reused 0 (delta 0), pack-reused 9987
# Receiving objects: 100% (9987/9987), 10.32 MiB | 24.13 MiB/s, done.
# Resolving deltas: 100% (6924/6924), done.

# %%
# !pip install -qr /content/yolov5/requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 5.5 MB/s
#      |████████████████████████████████| 127 kB 47.5 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# awscli 1.22.9 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.

# %%
# !echo "Strawberry" > /content/OIDv4_ToolKit/classes.txt

# %%
# !python /content/OIDv4_ToolKit/convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Strawberry
# 100% 1257/1257 [01:51<00:00, 11.25it/s]
# Currently in subdirectory: validation
# Converting annotations for class:  Strawberry
# 100% 63/63 [00:04<00:00, 14.57it/s]

# %%
# !cp /content/OID/Dataset/train/Strawberry/*.jpg /content/traindata/images/train/
# !cp /content/OID/Dataset/train/Strawberry/*.txt /content/traindata/labels/train/
# !cp /content/OID/Dataset/validation/Strawberry/*.jpg /content/traindata/images/val/
# !cp /content/OID/Dataset/validation/Strawberry/*.txt /content/traindata/labels/val/

# %%
# !cp /content/OID/Dataset/train/Strawberry/*.jpg /content/drive/MyDrive/data/traindata/images/train/
# !cp /content/OID/Dataset/train/Strawberry/*.txt /content/drive/MyDrive/data/traindata/labels/train/
# !cp /content/OID/Dataset/validation/Strawberry/*.jpg /content/drive/MyDrive/data/traindata/images/val/
# !cp /content/OID/Dataset/validation/Strawberry/*.txt /content/drive/MyDrive/data/traindata/labels/val/

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# !python train.py --batch 8 --epochs 30 --data custom_data.yaml --weights yolov5x.pt --save-period 5
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=30, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=5, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-97-geb51ffd torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/data/yolos/weights/best.pt --conf 0.25 --source /content/drive/MyDrive/data/yolos/2.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/data/yolos/weights/best.pt'], source=/content/drive/MyDrive/data/yolos/2.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-97-geb51ffd torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# image 1/1 /content/drive/MyDrive/data/yolos/2.jpg: 640x480 5 Strawberrys, Done. (0.193s)
# Speed: 0.5ms pre-process, 192.6ms inference, 2.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4
